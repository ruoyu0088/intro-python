# %% [markdown]
# # 交通事故データ解析

# %%
import cufflinks
cufflinks.go_offline()
import pandas as pd
from glob import glob

# %% [markdown]
# ## CSVデータ読み込み

# %%
df = pd.concat([pd.read_csv(fn, encoding="shift-jis") for fn in glob("data/交通事故-(平成*年).csv")])

# %% [markdown]
# ### 最初の5行

# %%
df.head()
# Out:
#    事故内容  事故類型   名称        地点経度       地点緯度                当事者種別 所轄警察署     発生場所  \
# 0  軽傷事故  車両相互  全事故  133.476678  35.270006            普通乗用×普通乗用   黒坂署  江府町大字武庫
# 1  軽傷事故  車両相互  全事故  133.470894  35.362625             軽乗用×普通乗用   黒坂署    伯耆町岩立
# 2  軽傷事故  車両相互  全事故  133.402917  35.384747            自転車×軽乗用貨物   黒坂署    伯耆町大殿
# 3  軽傷事故  車両相互  全事故  133.398069  35.387817              軽乗用×軽乗用   黒坂署    伯耆町大殿
# 4  軽傷事故  車両相互  全事故  133.553078  35.295319  軽二輪×軽乗用貨物×二輪751ｃｃ以上   黒坂署  江府町大字助澤
#
#         発生年月日  経度  緯度
# 0  2012/12/12 NaN NaN
# 1  2012/11/18 NaN NaN
# 2  2012/11/18 NaN NaN
# 3  2012/11/02 NaN NaN
# 4  2012/07/15 NaN NaN

# %% [markdown]
# ### 最後の5行

# %%
df.tail()
# Out:
#       事故内容  事故類型     名称  地点経度  地点緯度     当事者種別 所轄警察署         発生場所       発生年月日  \
# 1350  軽傷事故  人対車両  歩行者事故   NaN   NaN   軽乗用×歩行者   米子署        米子市石井  2015/12/20
# 1351  重傷事故  人対車両  歩行者事故   NaN   NaN  普通乗用×歩行者   境港署       境港市蓮池町  2015/11/15
# 1352  重傷事故  人対車両  歩行者事故   NaN   NaN  普通乗用×歩行者   黒坂署     日野郡日野町根雨  2015/11/25
# 1353  死亡事故  人対車両  歩行者事故   NaN   NaN   軽乗用×歩行者   黒坂署     日野郡日野町本郷  2015/12/23
# 1354  重傷事故  人対車両  歩行者事故   NaN   NaN  普通乗用×歩行者   黒坂署  日野郡江府町大字大河原   2015/11/4
#
#               経度         緯度
# 1350  133.344970  35.404800
# 1351  133.224206  35.539372
# 1352  133.441388  35.242385
# 1353  133.430703  35.237712
# 1354  133.549556  35.345829

# %% [markdown]
# ### 二つの列をマージする

# %% [markdown]
# CSVデータでは"地点経度"と"経度"のような重複な列がある、この２列を一つの列にする。

# %%
for col in ["経度", "緯度"]:
    df[col] = df[col].combine_first(df["地点" + col])
df2 = df.drop(["地点経度", "地点緯度"], axis=1)
df2.head()
# Out:
#    事故内容  事故類型   名称                当事者種別 所轄警察署     発生場所       発生年月日  \
# 0  軽傷事故  車両相互  全事故            普通乗用×普通乗用   黒坂署  江府町大字武庫  2012/12/12
# 1  軽傷事故  車両相互  全事故             軽乗用×普通乗用   黒坂署    伯耆町岩立  2012/11/18
# 2  軽傷事故  車両相互  全事故            自転車×軽乗用貨物   黒坂署    伯耆町大殿  2012/11/18
# 3  軽傷事故  車両相互  全事故              軽乗用×軽乗用   黒坂署    伯耆町大殿  2012/11/02
# 4  軽傷事故  車両相互  全事故  軽二輪×軽乗用貨物×二輪751ｃｃ以上   黒坂署  江府町大字助澤  2012/07/15
#
#            経度         緯度
# 0  133.476678  35.270006
# 1  133.470894  35.362625
# 2  133.402917  35.384747
# 3  133.398069  35.387817
# 4  133.553078  35.295319

# %% [markdown]
# 同じ日付、同じ場所で発生した事故を重複入力の可能性があるので、重複したデータを削除します。

# %%
df2.drop_duplicates(subset=["発生年月日", "経度", "緯度"], inplace=True)

# %% [markdown]
# ## データの統計

# %% [markdown]
# ### 事故内容の統計

# %%
事故内容 = pd.value_counts(df2["事故内容"])
事故内容
# Out:
# 軽傷事故    3529
# 重傷事故     751
# 死亡事故     106
# 人対車両       1
# 車両相互       1
# Name: 事故内容, dtype: int64

# %% [markdown]
# "車両相互"と"人対車両"は"事故内容"ではなく、"事故類型"のはずです。データ記入のミスだと思うので、該当する行を削除する。

# %%
df3 = df2[df2.事故内容.isin(事故内容[:3].index)]

# %% [markdown]
# "当事者種別"列を"×"で分割し、当事者の度数分布図を出力します。

# %%
当事者 = df3["当事者種別"].str.get_dummies("×").sum().sort_values()
当事者[当事者 >= 50].iplot(kind="bar", dimensions=(800, 500))
# Out:
# <div id="06ba9f83-b6f0-42c6-a885-651b83be951f" style="height: 500; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("06ba9f83-b6f0-42c6-a885-651b83be951f", [{"name": null, "type": "bar", "x": ["\u5927\u578b\u8ca8\u7269", "\u4e2d\u578b\u8ca8\u7269", "\u539f\u4ed8", "\u4e57\u7528\u8eca", "\u7269\u4ef6\u7b49", "\u666e\u901a\u8ca8\u7269", "\u8efd\u8ca8\u7269", "\u8efd\u4e57\u7528\u8ca8\u7269", "\u6b69\u884c\u8005", "\u81ea\u8ee2\u8eca", "\u8efd\u4e57\u7528", "\u666e\u901a\u4e57\u7528"], "y": [88, 97, 99, 103, 121, 235, 337, 417, 463, 593, 2382, 2546], "text": "", "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "orientation": "v"}], {"width": 800, "paper_bgcolor": "#F5F6F9", "height": 500, "legend": {"font": {"color": "#4D5663"}, "bgcolor": "#F5F6F9"}, "xaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "showgrid": true, "title": "", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED"}, "plot_bgcolor": "#F5F6F9", "yaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "showgrid": true, "title": "", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED"}, "titlefont": {"color": "#4D5663"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# 各個"事故内容"にたいして、"当事者種別"を統計します。

# %%
事故原因 = df3.groupby("事故内容").apply(lambda o:o["当事者種別"].str.get_dummies("×").sum()).unstack(0).fillna(0)
事故原因 = 事故原因.loc[当事者.index]
事故原因.tail()
# Out:
# 事故内容   死亡事故    軽傷事故   重傷事故
# 軽乗用貨物   8.0   344.0   65.0
# 歩行者    39.0   241.0  183.0
# 自転車    11.0   406.0  176.0
# 軽乗用    40.0  2004.0  338.0
# 普通乗用   39.0  2182.0  325.0

# %% [markdown]
# 50件事故以上の"当事者種別"にたいして、"事故原因"の割合図を出力します。

# %%
事故原因[事故原因.sum(axis=1) > 50].iplot(kind="bar", dimensions=(800, 500), barmode="stack")
# Out:
# <div id="7b64139d-c82d-4327-a8f5-387c9eacd345" style="height: 500; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7b64139d-c82d-4327-a8f5-387c9eacd345", [{"name": "\u6b7b\u4ea1\u4e8b\u6545", "type": "bar", "x": ["\u5927\u578b\u8ca8\u7269", "\u4e2d\u578b\u8ca8\u7269", "\u539f\u4ed8", "\u4e57\u7528\u8eca", "\u7269\u4ef6\u7b49", "\u666e\u901a\u8ca8\u7269", "\u8efd\u8ca8\u7269", "\u8efd\u4e57\u7528\u8ca8\u7269", "\u6b69\u884c\u8005", "\u81ea\u8ee2\u8eca", "\u8efd\u4e57\u7528", "\u666e\u901a\u4e57\u7528"], "y": [16.0, 5.0, 1.0, 3.0, 22.0, 2.0, 9.0, 8.0, 39.0, 11.0, 40.0, 39.0], "text": "", "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "orientation": "v"}, {"name": "\u8efd\u50b7\u4e8b\u6545", "type": "bar", "x": ["\u5927\u578b\u8ca8\u7269", "\u4e2d\u578b\u8ca8\u7269", "\u539f\u4ed8", "\u4e57\u7528\u8eca", "\u7269\u4ef6\u7b49", "\u666e\u901a\u8ca8\u7269", "\u8efd\u8ca8\u7269", "\u8efd\u4e57\u7528\u8ca8\u7269", "\u6b69\u884c\u8005", "\u81ea\u8ee2\u8eca", "\u8efd\u4e57\u7528", "\u666e\u901a\u4e57\u7528"], "y": [52.0, 76.0, 56.0, 83.0, 44.0, 204.0, 264.0, 344.0, 241.0, 406.0, 2004.0, 2182.0], "text": "", "marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "orientation": "v"}, {"name": "\u91cd\u50b7\u4e8b\u6545", "type": "bar", "x": ["\u5927\u578b\u8ca8\u7269", "\u4e2d\u578b\u8ca8\u7269", "\u539f\u4ed8", "\u4e57\u7528\u8eca", "\u7269\u4ef6\u7b49", "\u666e\u901a\u8ca8\u7269", "\u8efd\u8ca8\u7269", "\u8efd\u4e57\u7528\u8ca8\u7269", "\u6b69\u884c\u8005", "\u81ea\u8ee2\u8eca", "\u8efd\u4e57\u7528", "\u666e\u901a\u4e57\u7528"], "y": [20.0, 16.0, 42.0, 17.0, 55.0, 29.0, 64.0, 65.0, 183.0, 176.0, 338.0, 325.0], "text": "", "marker": {"color": "rgba(50, 171, 96, 0.6)", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1}}, "orientation": "v"}], {"width": 800, "paper_bgcolor": "#F5F6F9", "height": 500, "legend": {"traceorder": "normal", "font": {"color": "#4D5663"}, "bgcolor": "#F5F6F9"}, "xaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "showgrid": true, "title": "", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED"}, "plot_bgcolor": "#F5F6F9", "yaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "showgrid": true, "title": "", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED"}, "barmode": "stack", "titlefont": {"color": "#4D5663"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# 事故を地図上に表すため、データを整理します。

# %%
df_map = pd.DataFrame({
        "x":df["経度"],
        "y":df["緯度"],
        "icon":"car",
        "color":"green",
        "text":df["発生年月日"] + ": " + df["当事者種別"]
    })

s = df["当事者種別"]
for icon, pattern in zip(["truck", "motorcycle", "bicycle", "user"], ["貨物", "原付|二輪", "自転車", "歩行者"]):
    df_map.loc[s.str.contains(pattern), "icon"] = icon
    
s = df["事故内容"]
for color, pattern in zip(["green", "orange", "red"], ["軽傷", "重傷", "死亡"]):
    df_map.loc[s.str.contains(pattern), "color"] = color
    
df_map.dropna(inplace=True)
df_map.head()
# Out:
#     color     icon                     text           x          y
# 0   green      car  2014/9/18: 軽乗用×軽乗用×普通乗用  133.364474  35.431586
# 1  orange      car      2014/10/4: 軽乗用×普通乗用  134.231846  35.456160
# 2  orange     user       2014/11/5: 軽乗用×歩行者  133.335616  35.423464
# 3   green  bicycle      2014/11/15: 軽乗用×自転車  133.348036  35.435128
# 4   green  bicycle      2014/11/20: 軽乗用×自転車  133.337914  35.440842

# %% [markdown]
# 地図を出力します。

# %%
import folium
from fastmarker import FastMarkerCluster

fig = folium.Figure()
map_ = folium.Map(location=[df_map.y.mean(), df_map.x.mean()], zoom_start=10)

def create_marker(row):
    icon = L.AwesomeMarkers.icon({
                        icon: row.icon,
                        prefix: 'fa',
                        markerColor: row.color,
                        })    
    marker = L.marker(L.LatLng(row.y, row.x))
    marker.setIcon(icon)
    marker.bindPopup(row.text)
    marker.on('mouseover', lambda e:marker.openPopup())
    marker.on('mouseout', lambda e:marker.closePopup())
    return marker

cluster = FastMarkerCluster(df_map.to_json(orient="records"), 
                            callback=create_marker, 
                            settings={"disableClusteringAtZoom":15}).add_to(map_)
map_.add_to(fig)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
